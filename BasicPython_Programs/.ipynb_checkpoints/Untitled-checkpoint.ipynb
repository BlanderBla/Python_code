# %%
import pandas as pd

# %%
# Read Spotify_Song_attributes.csv file
df = pd.read_csv('Spotify_Song_Attributes.csv')
print(df)
# Out:
#                                                trackName  \
# 0                                               "Honest"
# 1      "In The Hall Of The Mountain King" from Peer G...
# 2                                     #BrooklynBloodPop!
# 3                                                    $10
# 4                             (I Just) Died In Your Arms
# ...                                                  ...
# 10075                                 Younger with Time.
# 10076                Your Latest Trick - Remastered 1996
# 10077                Your Love Is My Drug (8 Bit Slowed)
# 10078                                         Your Power
# 10079                            Your Voice / Bethel, NY
#
#                       artistName  msPlayed              genre  danceability  \
# 0                   Nico Collins    191772                NaN         0.476
# 1      London Symphony Orchestra   1806234  british orchestra         0.475
# ...

# %%
# Ordered file throught the column 'artisName'
df_sortedArtis = df.sort_values(by='artistName', ascending=True)
print(df_sortedArtis)
# Out:
#                        trackName     artistName  msPlayed              genre  \
# 4457                  The Hammer            !!!      3130  metallic hardcore
# 6783  Even When The Water's Cold            !!!    227066  alternative dance
# 1743  Even When The Water's Cold            !!!    227066  alternative dance
# 9497                  The Hammer            !!!      3130  metallic hardcore
# 7023                       GOSHA           $NOT    360000      aesthetic rap
# ...                          ...            ...       ...                ...
# 5988                         アーチ  羽柴夏樹（ＣＶ：松岡禎丞）      5901                NaN
# 937           「聴く小説・すずめの戸締まり」第1話  聴く小説・すずめの戸締まり     12323                NaN
# 5977          「聴く小説・すずめの戸締まり」第1話  聴く小説・すずめの戸締まり     12323                NaN
# 6028                          有些            颜人中      7930  chinese viral pop
# 988                           有些            颜人中      7930  chinese viral pop
#
# ...

# %%
print(df_sortedArtis.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(df_sortedSArtists.isnull().sum())
#
# NameError: name 'df_sortedSArtists' is not defined

# %%
df_sortedArtis.to_csv("Spotify_Song_Ordered.csv", index=False)
